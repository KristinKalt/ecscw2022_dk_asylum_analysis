# %%
import sys
import pandas as pd
import numpy as np
import csv
import json
#from itertools import combinations

# %%
df = pd.read_json('data/dk_asylum_data.json', encoding='utf-8')
df.head()
# Out:
#    id                                      asylum_motive  country  \
# 0   0                                         [Bortfald]     Irak
# 1   1  [Konsekvensstatus,  Sur Place,  Politiske forh...  Tyrkiet
# 2   2  [Sur Place,  Inddragelse/forlængelse,  Generel...   Syrien
# 3   3  [Udsendelse (§ 49 a m.v.),  Øvrige modsætnings...    Tchad
# 4   4                    [Sur Place,  Politiske forhold]     Iran
#
#                                                 text  hasText
# 0          Nævnet omgjorde i marts 2022 Udlænding...     True
# 1          Nævnet meddelte i marts 2022 opholdsti...     True
# 2          Nævnet omgjorde i marts 2022 Udlænding...     True
# 3          Nævnet stadfæstede i marts 2022 Udlænd...     True
# 4          Nævnet meddelte i marts 2022 opholdsti...     True

# %% [markdown]
# The following list of asylum motives is extracted from the search page of the data set at https://fln.dk/da/Praksis. There might be additional motives that were added at a later point.

# %%
motives = ["Agents of Persecution",
"Anden kønsrelateret forfølgelse",
"Asylsagsproceduren",
"Chikane",
"Etniske forhold",
"Familier med børn",
"Familierelationer og ægteskabslignende forhold",
"Generelle forhold",
"Helbredsmæssige forhold",
"Kriminelle forhold",
"Kønsrelateret forfølgelse",
"LGBT",
"Militære forhold",
"Modtageforhold",
"Nationalitet",
"Overgreb",
"Politiske forhold",
"Privatretlig forhold",
"Privatretlig konflikt",
"Religiøse forhold",
"Seksuelle forhold",
"Tilbageholdelse",
"Tilknyt bistand oprørsgruppe",
"Tortur",
"Udrejseforhold",
"Uforholdsmæssig straf",
"Ægteskabelige forhold",
"Ændrede forhold",
"Øvrige modsætningsforhold til myndighederne"
]

gender_motives = ["Anden kønsrelateret forfølgelse",
                  "Kønsrelateret forfølgelse",
                  "LGBT",
                  "Seksuelle forhold",
                  "Ægteskabelige forhold"
                    ]

# %% [markdown]
# Extracts the asylum motives from the column "asylum_motives" and turns the list into columns, one column for each asylum motive

# %%
df_motives = pd.DataFrame(columns=gender_motives)

def mark_motive(text, str_id):
    new_list = [item.strip() for item in text]
    for item in new_list:
        if item in gender_motives:
            df_motives.loc[str_id, item] = 1.0
    df_motives.loc[str_id, 'text'] = df.loc[str_id, 'text']


for index, row in df.iterrows():
    mark_motive(row['asylum_motive'], index)


print("Shape of the df with motives as columns", df_motives.shape)
# Out:
# Shape of the df with motives as columns (9301, 6)

# %%
def get_number_of_cases_with2_gender_asyl_motives():
    two_motives = df_motives[gender_motives].copy()
    two_motives['count'] = two_motives.sum(axis=1)    
    two_motives =two_motives[two_motives['count'] > 1.0]
    return len(two_motives)

print("Number of cases with 2 gender asylum motives:", get_number_of_cases_with2_gender_asyl_motives())
# Out:
# Number of cases with 2 gender asylum motives: 164

# %% [markdown]
# # Topics Analysis

# %%
def get_num_word(df, word):
    df[word] = np.where(df.text.str.contains(word), 1, 0)
    return df[word].sum()

# %%
col_rename = {"Kønsrelateret forfølgelse": "Gender-related persecution",
             "LGBT": "LGBT",
             "Seksuelle forhold": "Sexual conditions",
             "Ægteskabelige forhold": "Marital conditions",
             "Anden kønsrelateret forfølgelse": "Other gender-related persecution",
                   }
words = [
    'tvangsgift',
    'homoseks',
    'lesbisk',
    'prostitution',
    'voldt',
    'enlig',
    'transkøn',
    'abort',
    'sterilis',
    'biseks',
    'transvest',
    'menneskehandel',
    'traffick',
    'omskåret',
    'omskæring'
]

grouping = {
    'Homosexuality': ['homoseks', 'lesbisk'],
    'Human trafficking': ['menneskehandel', 'traffick'],
    'Female genital mutilation': ['omskåret', 'omskæring'],
    'Forced marriage': ['tvangsgift'],
    'Forced prostitution': ['prostitution'],
    'Rape': ['voldt'],
    'Transgenderism': ['transkøn'],
    'Forced abortion': ['abort'],
    'Forced sterilisation': ['sterilis'],
    'Bisexuality': ['biseks'],
    'Transvestism': ['transvest']
}

# %%
def get_count_per_word(word, cat):
    df_motives[word] = np.where(df_motives.text.str.contains(word), 1, 0)

def group_topic(cat, word_list):
    df_count = df_motives[df_motives[cat] == 1.0][word_list]
    return df_count.any(axis=1).sum()

def make_analysis_table():
    index_topics = grouping.keys()
    df_res = pd.DataFrame(columns=gender_motives, index=index_topics)
    for cat in gender_motives:
        for word in words:
            get_count_per_word(word, cat)
        for topic, word_list in grouping.items():
            df_res.at[topic, cat] = group_topic(cat, word_list)
    df_res.rename(columns=col_rename, inplace=True)
    return df_res

df_topic_count = make_analysis_table()
df_topic_count
# Out:
#                           Other gender-related persecution  \
# Homosexuality                                            2
# Human trafficking                                       21
# Female genital mutilation                              116
# Forced marriage                                         26
# Forced prostitution                                      8
# Rape                                                    35
# Transgenderism                                           0
# Forced abortion                                          3
# Forced sterilisation                                     2
# Bisexuality                                              0
# Transvestism                                             0
#
#                           Gender-related persecution LGBT Sexual conditions  \
# Homosexuality                                     29  192                46
# Human trafficking                                 17    3                 7
# Female genital mutilation                         23    0                12
# Forced marriage                                   22    1                26
# Forced prostitution                               14    4                 8
# Rape                                              51   26                99
# Transgenderism                                     0    5                 0
# Forced abortion                                    3    2                15
# Forced sterilisation                               3    0                 1
# Bisexuality                                        1   34                 6
# Transvestism                                       0    0                 0
#
#                           Marital conditions
# Homosexuality                              6
# Human trafficking                          2
# Female genital mutilation                 31
# Forced marriage                           75
# Forced prostitution                        2
# Rape                                      54
# Transgenderism                             1
# Forced abortion                           19
# Forced sterilisation                       0
# Bisexuality                                0
# Transvestism                               0

# %%
def make_topic_modelling_table():
    cols = df_topic_count.columns
    df_res_relative = pd.DataFrame(columns=cols, index=grouping.keys())
    df_res_relative[cols] = df_topic_count[cols].div(df_topic_count[cols].sum(axis=0), axis=1)
    df_res_relative['Total'] = df_topic_count[cols].sum(axis = 1)
    df_res_relative.loc['Total'] = df_topic_count.sum()
    return df_res_relative

df_topic_model = make_topic_modelling_table()

print("Topic analysis table with percentages:")
df_topic_model
# Out:
# Topic analysis table with percentages:
#                           Other gender-related persecution  \
# Homosexuality                                      0.00939
# Human trafficking                                 0.098592
# Female genital mutilation                         0.544601
# Forced marriage                                   0.122066
# Forced prostitution                               0.037559
# Rape                                              0.164319
# Transgenderism                                         0.0
# Forced abortion                                   0.014085
# Forced sterilisation                               0.00939
# Bisexuality                                            0.0
# Transvestism                                           0.0
# Total                                                  213
#
#                           Gender-related persecution      LGBT  \
# Homosexuality                               0.177914  0.719101
# Human trafficking                           0.104294  0.011236
# Female genital mutilation                   0.141104       0.0
# Forced marriage                             0.134969  0.003745
# Forced prostitution                          0.08589  0.014981
# Rape                                        0.312883  0.097378
# Transgenderism                                   0.0  0.018727
# Forced abortion                             0.018405  0.007491
# Forced sterilisation                        0.018405       0.0
# Bisexuality                                 0.006135  0.127341
# Transvestism                                     0.0       0.0
# Total                                            163       267
#
#                           Sexual conditions Marital conditions  Total
# Homosexuality                      0.209091           0.031579  275.0
# Human trafficking                  0.031818           0.010526   50.0
# Female genital mutilation          0.054545           0.163158  182.0
# Forced marriage                    0.118182           0.394737  150.0
# Forced prostitution                0.036364           0.010526   36.0
# Rape                                   0.45           0.284211  265.0
# Transgenderism                          0.0           0.005263    6.0
# Forced abortion                    0.068182                0.1   42.0
# Forced sterilisation               0.004545                0.0    6.0
# Bisexuality                        0.027273                0.0   41.0
# Transvestism                            0.0                0.0    0.0
# Total                                   220                190    NaN

# %%
def save_topics_table():
    #Round to two digits to print nicely
    df_save = df_topic_model.copy()
    df_save = df_save.astype(float)
    df_save.to_csv('data/topic_modelling.csv')

save_topics_table()

# %% [markdown]
# # Co-occurrence Matrix

# %% [markdown]
# Create dataframe to make co-occurrence matrix from:

# %%
df_motives_all = pd.DataFrame(columns=motives)

def mark_motive(text, str_id):
    new_list = [item.strip() for item in text]
    for item in new_list:
        if item in motives:
            df_motives_all.loc[str_id, item] = 1.0

def prepare_df_for_coocc_matrix():                     
    for index, row in df.iterrows():
        mark_motive(row['asylum_motive'], index)
    df_motives_all.fillna(0, inplace=True)
    return df_motives_all

prepped_df = prepare_df_for_coocc_matrix()
    
print("Shape of df with all asylum motives:", df_motives_all.shape)
# Out:
# Shape of df with all asylum motives: (8967, 29)

# %%
def get_co_occ_matrix(df):
    return df.T.dot(df_motives_all)

co_matrix = get_co_occ_matrix(prepped_df)
co_matrix.to_csv('data/co_matrix.csv')

# %%
co_matrix
# Out:
#                                                 Agents of Persecution  \
# Agents of Persecution                                          2520.0
# Anden kønsrelateret forfølgelse                                  65.0
# Asylsagsproceduren                                                0.0
# Chikane                                                         116.0
# Etniske forhold                                                 197.0
# Familier med børn                                                 0.0
# Familierelationer og ægteskabslignende forhold                    0.0
# Generelle forhold                                               582.0
# Helbredsmæssige forhold                                           2.0
# Kriminelle forhold                                               77.0
# Kønsrelateret forfølgelse                                        81.0
# LGBT                                                             14.0
# Militære forhold                                                142.0
# Modtageforhold                                                    0.0
# Nationalitet                                                     26.0
# Overgreb                                                         95.0
# Politiske forhold                                               257.0
# Privatretlig forhold                                            511.0
# Privatretlig konflikt                                            22.0
# Religiøse forhold                                               220.0
# Seksuelle forhold                                                73.0
# Tilbageholdelse                                                  29.0
# Tilknyt bistand oprørsgruppe                                     50.0
# Tortur                                                           67.0
# Udrejseforhold                                                   22.0
# Uforholdsmæssig straf                                             4.0
# Ægteskabelige forhold                                            91.0
# Ændrede forhold                                                   0.0
# Øvrige modsætningsforhold til myndighederne                      12.0
#
#                                                 Anden kønsrelateret forfølgelse  \
# Agents of Persecution                                                      65.0
# Anden kønsrelateret forfølgelse                                           182.0
# Asylsagsproceduren                                                          0.0
# Chikane                                                                     1.0
# Etniske forhold                                                             7.0
# Familier med børn                                                           0.0
# Familierelationer og ægteskabslignende forhold                              0.0
# Generelle forhold                                                          45.0
# Helbredsmæssige forhold                                                     1.0
# Kriminelle forhold                                                          2.0
# Kønsrelateret forfølgelse                                                   0.0
# LGBT                                                                        2.0
# Militære forhold                                                            1.0
# Modtageforhold                                                              1.0
# Nationalitet                                                                1.0
# Overgreb                                                                    4.0
# Politiske forhold                                                           6.0
# Privatretlig forhold                                                       42.0
# Privatretlig konflikt                                                       3.0
# Religiøse forhold                                                           4.0
# Seksuelle forhold                                                          16.0
# Tilbageholdelse                                                             0.0
# Tilknyt bistand oprørsgruppe                                                5.0
# Tortur                                                                      1.0
# Udrejseforhold                                                              1.0
# Uforholdsmæssig straf                                                       0.0
# Ægteskabelige forhold                                                      24.0
# Ændrede forhold                                                             1.0
# Øvrige modsætningsforhold til myndighederne                                 1.0
#
#                                                 Asylsagsproceduren  Chikane  \
# Agents of Persecution                                          0.0    116.0
# Anden kønsrelateret forfølgelse                                0.0      1.0
# Asylsagsproceduren                                            48.0      9.0
# Chikane                                                        9.0    473.0
# Etniske forhold                                                0.0     87.0
# Familier med børn                                              2.0      0.0
# Familierelationer og ægteskabslignende forhold                 5.0      3.0
# Generelle forhold                                              8.0    141.0
# Helbredsmæssige forhold                                       16.0      9.0
# Kriminelle forhold                                             0.0     27.0
# Kønsrelateret forfølgelse                                      0.0     26.0
# LGBT                                                           1.0     14.0
# Militære forhold                                               0.0     39.0
# Modtageforhold                                                24.0      2.0
# Nationalitet                                                   0.0     29.0
# Overgreb                                                       0.0     80.0
# Politiske forhold                                              0.0    131.0
# Privatretlig forhold                                           5.0    110.0
# Privatretlig konflikt                                          0.0      5.0
# Religiøse forhold                                              0.0     69.0
# Seksuelle forhold                                              0.0     20.0
# Tilbageholdelse                                                0.0     25.0
# Tilknyt bistand oprørsgruppe                                   0.0     11.0
# Tortur                                                         0.0     17.0
# Udrejseforhold                                                 0.0     17.0
# Uforholdsmæssig straf                                          0.0      8.0
# Ægteskabelige forhold                                          1.0     12.0
# Ændrede forhold                                                0.0      0.0
# Øvrige modsætningsforhold til myndighederne                    0.0      7.0
#
#                                                 Etniske forhold  \
# Agents of Persecution                                     197.0
# Anden kønsrelateret forfølgelse                             7.0
# Asylsagsproceduren                                          0.0
# Chikane                                                    87.0
# Etniske forhold                                           969.0
# Familier med børn                                           0.0
# Familierelationer og ægteskabslignende forhold              0.0
# Generelle forhold                                         310.0
# Helbredsmæssige forhold                                     1.0
# Kriminelle forhold                                         25.0
# Kønsrelateret forfølgelse                                  29.0
# LGBT                                                        4.0
# Militære forhold                                           55.0
# Modtageforhold                                              0.0
# Nationalitet                                              108.0
# Overgreb                                                   61.0
# Politiske forhold                                         341.0
# Privatretlig forhold                                      133.0
# Privatretlig konflikt                                       2.0
# Religiøse forhold                                         117.0
# Seksuelle forhold                                          23.0
# Tilbageholdelse                                            52.0
# Tilknyt bistand oprørsgruppe                               21.0
# Tortur                                                     65.0
# Udrejseforhold                                             33.0
# Uforholdsmæssig straf                                      10.0
# Ægteskabelige forhold                                      17.0
# Ændrede forhold                                             1.0
# Øvrige modsætningsforhold til myndighederne                14.0
#
#                                                 Familier med børn  \
# Agents of Persecution                                         0.0
# Anden kønsrelateret forfølgelse                               0.0
# Asylsagsproceduren                                            2.0
# Chikane                                                       0.0
# Etniske forhold                                               0.0
# Familier med børn                                             5.0
# Familierelationer og ægteskabslignende forhold                1.0
# Generelle forhold                                             2.0
# Helbredsmæssige forhold                                       3.0
# Kriminelle forhold                                            0.0
# Kønsrelateret forfølgelse                                     0.0
# LGBT                                                          0.0
# Militære forhold                                              0.0
# Modtageforhold                                                2.0
# Nationalitet                                                  0.0
# Overgreb                                                      0.0
# Politiske forhold                                             0.0
# Privatretlig forhold                                          0.0
# Privatretlig konflikt                                         0.0
# Religiøse forhold                                             0.0
# Seksuelle forhold                                             0.0
# Tilbageholdelse                                               0.0
# Tilknyt bistand oprørsgruppe                                  0.0
# Tortur                                                        0.0
# Udrejseforhold                                                0.0
# Uforholdsmæssig straf                                         0.0
# Ægteskabelige forhold                                         0.0
# Ændrede forhold                                               0.0
# Øvrige modsætningsforhold til myndighederne                   0.0
#
#                                                 Familierelationer og ægteskabslignende forhold  \
# Agents of Persecution                                                                      0.0
# Anden kønsrelateret forfølgelse                                                            0.0
# Asylsagsproceduren                                                                         5.0
# Chikane                                                                                    3.0
# Etniske forhold                                                                            0.0
# Familier med børn                                                                          1.0
# Familierelationer og ægteskabslignende forhold                                            30.0
# Generelle forhold                                                                          3.0
# Helbredsmæssige forhold                                                                    7.0
# Kriminelle forhold                                                                         0.0
# Kønsrelateret forfølgelse                                                                  2.0
# LGBT                                                                                       0.0
# Militære forhold                                                                           0.0
# Modtageforhold                                                                             9.0
# Nationalitet                                                                               0.0
# Overgreb                                                                                   0.0
# Politiske forhold                                                                          0.0
# Privatretlig forhold                                                                       3.0
# Privatretlig konflikt                                                                      0.0
# Religiøse forhold                                                                          0.0
# Seksuelle forhold                                                                          1.0
# Tilbageholdelse                                                                            0.0
# Tilknyt bistand oprørsgruppe                                                               0.0
# Tortur                                                                                     0.0
# Udrejseforhold                                                                             0.0
# Uforholdsmæssig straf                                                                      0.0
# Ægteskabelige forhold                                                                      2.0
# Ændrede forhold                                                                            0.0
# Øvrige modsætningsforhold til myndighederne                                                1.0
#
#                                                 Generelle forhold  \
# Agents of Persecution                                       582.0
# Anden kønsrelateret forfølgelse                              45.0
# Asylsagsproceduren                                            8.0
# Chikane                                                     141.0
# Etniske forhold                                             310.0
# Familier med børn                                             2.0
# Familierelationer og ægteskabslignende forhold                3.0
# Generelle forhold                                          1988.0
# Helbredsmæssige forhold                                      28.0
# Kriminelle forhold                                           53.0
# Kønsrelateret forfølgelse                                    54.0
# LGBT                                                         16.0
# Militære forhold                                            207.0
# Modtageforhold                                               15.0
# Nationalitet                                                138.0
# Overgreb                                                     64.0
# Politiske forhold                                           400.0
# Privatretlig forhold                                        338.0
# Privatretlig konflikt                                         9.0
# Religiøse forhold                                           162.0
# Seksuelle forhold                                            49.0
# Tilbageholdelse                                              28.0
# Tilknyt bistand oprørsgruppe                                 41.0
# Tortur                                                       40.0
# Udrejseforhold                                               53.0
# Uforholdsmæssig straf                                        11.0
# Ægteskabelige forhold                                        70.0
# Ændrede forhold                                               6.0
# Øvrige modsætningsforhold til myndighederne                  66.0
#
#                                                 Helbredsmæssige forhold  \
# Agents of Persecution                                               2.0
# Anden kønsrelateret forfølgelse                                     1.0
# Asylsagsproceduren                                                 16.0
# Chikane                                                             9.0
# Etniske forhold                                                     1.0
# Familier med børn                                                   3.0
# Familierelationer og ægteskabslignende forhold                      7.0
# Generelle forhold                                                  28.0
# Helbredsmæssige forhold                                            70.0
# Kriminelle forhold                                                  0.0
# Kønsrelateret forfølgelse                                           1.0
# LGBT                                                                0.0
# Militære forhold                                                    3.0
# Modtageforhold                                                     18.0
# Nationalitet                                                        2.0
# Overgreb                                                            3.0
# Politiske forhold                                                   7.0
# Privatretlig forhold                                               13.0
# Privatretlig konflikt                                               0.0
# Religiøse forhold                                                   2.0
# Seksuelle forhold                                                   0.0
# Tilbageholdelse                                                     3.0
# Tilknyt bistand oprørsgruppe                                        1.0
# Tortur                                                              1.0
# Udrejseforhold                                                      1.0
# Uforholdsmæssig straf                                               0.0
# Ægteskabelige forhold                                               4.0
# Ændrede forhold                                                     0.0
# Øvrige modsætningsforhold til myndighederne                         7.0
#
#                                                 Kriminelle forhold  ...  \
# Agents of Persecution                                         77.0  ...
# Anden kønsrelateret forfølgelse                                2.0  ...
# Asylsagsproceduren                                             0.0  ...
# Chikane                                                       27.0  ...
# Etniske forhold                                               25.0  ...
# Familier med børn                                              0.0  ...
# Familierelationer og ægteskabslignende forhold                 0.0  ...
# Generelle forhold                                             53.0  ...
# Helbredsmæssige forhold                                        0.0  ...
# Kriminelle forhold                                           287.0  ...
# Kønsrelateret forfølgelse                                     10.0  ...
# LGBT                                                           3.0  ...
# Militære forhold                                              30.0  ...
# Modtageforhold                                                 0.0  ...
# Nationalitet                                                  13.0  ...
# Overgreb                                                      24.0  ...
# Politiske forhold                                             52.0  ...
# Privatretlig forhold                                          86.0  ...
# Privatretlig konflikt                                          3.0  ...
# Religiøse forhold                                             37.0  ...
# Seksuelle forhold                                             15.0  ...
# Tilbageholdelse                                               13.0  ...
# Tilknyt bistand oprørsgruppe                                   6.0  ...
# Tortur                                                        15.0  ...
# Udrejseforhold                                                 5.0  ...
# Uforholdsmæssig straf                                         15.0  ...
# Ægteskabelige forhold                                          7.0  ...
# Ændrede forhold                                                0.0  ...
# Øvrige modsætningsforhold til myndighederne                    2.0  ...
#
#                                                 Religiøse forhold  \
# Agents of Persecution                                       220.0
# Anden kønsrelateret forfølgelse                               4.0
# Asylsagsproceduren                                            0.0
# Chikane                                                      69.0
# Etniske forhold                                             117.0
# Familier med børn                                             0.0
# Familierelationer og ægteskabslignende forhold                0.0
# Generelle forhold                                           162.0
# Helbredsmæssige forhold                                       2.0
# Kriminelle forhold                                           37.0
# Kønsrelateret forfølgelse                                    21.0
# LGBT                                                         21.0
# Militære forhold                                             64.0
# Modtageforhold                                                0.0
# Nationalitet                                                 15.0
# Overgreb                                                     38.0
# Politiske forhold                                           332.0
# Privatretlig forhold                                        206.0
# Privatretlig konflikt                                         8.0
# Religiøse forhold                                          1426.0
# Seksuelle forhold                                            51.0
# Tilbageholdelse                                               8.0
# Tilknyt bistand oprørsgruppe                                 10.0
# Tortur                                                       34.0
# Udrejseforhold                                               17.0
# Uforholdsmæssig straf                                         8.0
# Ægteskabelige forhold                                        59.0
# Ændrede forhold                                               0.0
# Øvrige modsætningsforhold til myndighederne                  14.0
#
#                                                 Seksuelle forhold  \
# Agents of Persecution                                        73.0
# Anden kønsrelateret forfølgelse                              16.0
# Asylsagsproceduren                                            0.0
# Chikane                                                      20.0
# Etniske forhold                                              23.0
# Familier med børn                                             0.0
# Familierelationer og ægteskabslignende forhold                1.0
# Generelle forhold                                            49.0
# Helbredsmæssige forhold                                       0.0
# Kriminelle forhold                                           15.0
# Kønsrelateret forfølgelse                                    46.0
# LGBT                                                          8.0
# Militære forhold                                              9.0
# Modtageforhold                                                2.0
# Nationalitet                                                  2.0
# Overgreb                                                     41.0
# Politiske forhold                                            35.0
# Privatretlig forhold                                        104.0
# Privatretlig konflikt                                         7.0
# Religiøse forhold                                            51.0
# Seksuelle forhold                                           369.0
# Tilbageholdelse                                               4.0
# Tilknyt bistand oprørsgruppe                                  4.0
# Tortur                                                        9.0
# Udrejseforhold                                                5.0
# Uforholdsmæssig straf                                         4.0
# Ægteskabelige forhold                                        55.0
# Ændrede forhold                                               0.0
# Øvrige modsætningsforhold til myndighederne                   4.0
#
#                                                 Tilbageholdelse  \
# Agents of Persecution                                      29.0
# Anden kønsrelateret forfølgelse                             0.0
# Asylsagsproceduren                                          0.0
# Chikane                                                    25.0
# Etniske forhold                                            52.0
# Familier med børn                                           0.0
# Familierelationer og ægteskabslignende forhold              0.0
# Generelle forhold                                          28.0
# Helbredsmæssige forhold                                     3.0
# Kriminelle forhold                                         13.0
# Kønsrelateret forfølgelse                                   5.0
# LGBT                                                        0.0
# Militære forhold                                           21.0
# Modtageforhold                                              0.0
# Nationalitet                                                5.0
# Overgreb                                                   48.0
# Politiske forhold                                          91.0
# Privatretlig forhold                                       23.0
# Privatretlig konflikt                                       0.0
# Religiøse forhold                                           8.0
# Seksuelle forhold                                           4.0
# Tilbageholdelse                                           147.0
# Tilknyt bistand oprørsgruppe                                0.0
# Tortur                                                     40.0
# Udrejseforhold                                             15.0
# Uforholdsmæssig straf                                       2.0
# Ægteskabelige forhold                                       1.0
# Ændrede forhold                                             0.0
# Øvrige modsætningsforhold til myndighederne                 7.0
#
#                                                 Tilknyt bistand oprørsgruppe  \
# Agents of Persecution                                                   50.0
# Anden kønsrelateret forfølgelse                                          5.0
# Asylsagsproceduren                                                       0.0
# Chikane                                                                 11.0
# Etniske forhold                                                         21.0
# Familier med børn                                                        0.0
# Familierelationer og ægteskabslignende forhold                           0.0
# Generelle forhold                                                       41.0
# Helbredsmæssige forhold                                                  1.0
# Kriminelle forhold                                                       6.0
# Kønsrelateret forfølgelse                                                0.0
# LGBT                                                                     1.0
# Militære forhold                                                        33.0
# Modtageforhold                                                           0.0
# Nationalitet                                                             9.0
# Overgreb                                                                12.0
# Politiske forhold                                                       61.0
# Privatretlig forhold                                                    16.0
# Privatretlig konflikt                                                    0.0
# Religiøse forhold                                                       10.0
# Seksuelle forhold                                                        4.0
# Tilbageholdelse                                                          0.0
# Tilknyt bistand oprørsgruppe                                           221.0
# Tortur                                                                  19.0
# Udrejseforhold                                                           9.0
# Uforholdsmæssig straf                                                    3.0
# Ægteskabelige forhold                                                    6.0
# Ændrede forhold                                                          1.0
# Øvrige modsætningsforhold til myndighederne                              8.0
#
#                                                 Tortur  Udrejseforhold  \
# Agents of Persecution                             67.0            22.0
# Anden kønsrelateret forfølgelse                    1.0             1.0
# Asylsagsproceduren                                 0.0             0.0
# Chikane                                           17.0            17.0
# Etniske forhold                                   65.0            33.0
# Familier med børn                                  0.0             0.0
# Familierelationer og ægteskabslignende forhold     0.0             0.0
# Generelle forhold                                 40.0            53.0
# Helbredsmæssige forhold                            1.0             1.0
# Kriminelle forhold                                15.0             5.0
# Kønsrelateret forfølgelse                          2.0             6.0
# LGBT                                               3.0             0.0
# Militære forhold                                  38.0            28.0
# Modtageforhold                                     0.0             0.0
# Nationalitet                                       6.0            11.0
# Overgreb                                          35.0             9.0
# Politiske forhold                                148.0            65.0
# Privatretlig forhold                              20.0            20.0
# Privatretlig konflikt                              1.0             0.0
# Religiøse forhold                                 34.0            17.0
# Seksuelle forhold                                  9.0             5.0
# Tilbageholdelse                                   40.0            15.0
# Tilknyt bistand oprørsgruppe                      19.0             9.0
# Tortur                                           274.0            11.0
# Udrejseforhold                                    11.0           141.0
# Uforholdsmæssig straf                              5.0             7.0
# Ægteskabelige forhold                              6.0             5.0
# Ændrede forhold                                    2.0             3.0
# Øvrige modsætningsforhold til myndighederne        6.0             7.0
#
#                                                 Uforholdsmæssig straf  \
# Agents of Persecution                                             4.0
# Anden kønsrelateret forfølgelse                                   0.0
# Asylsagsproceduren                                                0.0
# Chikane                                                           8.0
# Etniske forhold                                                  10.0
# Familier med børn                                                 0.0
# Familierelationer og ægteskabslignende forhold                    0.0
# Generelle forhold                                                11.0
# Helbredsmæssige forhold                                           0.0
# Kriminelle forhold                                               15.0
# Kønsrelateret forfølgelse                                         1.0
# LGBT                                                              0.0
# Militære forhold                                                 15.0
# Modtageforhold                                                    0.0
# Nationalitet                                                      2.0
# Overgreb                                                          8.0
# Politiske forhold                                                21.0
# Privatretlig forhold                                             11.0
# Privatretlig konflikt                                             0.0
# Religiøse forhold                                                 8.0
# Seksuelle forhold                                                 4.0
# Tilbageholdelse                                                   2.0
# Tilknyt bistand oprørsgruppe                                      3.0
# Tortur                                                            5.0
# Udrejseforhold                                                    7.0
# Uforholdsmæssig straf                                            62.0
# Ægteskabelige forhold                                             4.0
# Ændrede forhold                                                   0.0
# Øvrige modsætningsforhold til myndighederne                       0.0
#
#                                                 Ægteskabelige forhold  \
# Agents of Persecution                                            91.0
# Anden kønsrelateret forfølgelse                                  24.0
# Asylsagsproceduren                                                1.0
# Chikane                                                          12.0
# Etniske forhold                                                  17.0
# Familier med børn                                                 0.0
# Familierelationer og ægteskabslignende forhold                    2.0
# Generelle forhold                                                70.0
# Helbredsmæssige forhold                                           4.0
# Kriminelle forhold                                                7.0
# Kønsrelateret forfølgelse                                        13.0
# LGBT                                                              6.0
# Militære forhold                                                  6.0
# Modtageforhold                                                    1.0
# Nationalitet                                                     10.0
# Overgreb                                                         22.0
# Politiske forhold                                                30.0
# Privatretlig forhold                                            183.0
# Privatretlig konflikt                                            20.0
# Religiøse forhold                                                59.0
# Seksuelle forhold                                                55.0
# Tilbageholdelse                                                   1.0
# Tilknyt bistand oprørsgruppe                                      6.0
# Tortur                                                            6.0
# Udrejseforhold                                                    5.0
# Uforholdsmæssig straf                                             4.0
# Ægteskabelige forhold                                           487.0
# Ændrede forhold                                                   0.0
# Øvrige modsætningsforhold til myndighederne                       7.0
#
#                                                 Ændrede forhold  \
# Agents of Persecution                                       0.0
# Anden kønsrelateret forfølgelse                             1.0
# Asylsagsproceduren                                          0.0
# Chikane                                                     0.0
# Etniske forhold                                             1.0
# Familier med børn                                           0.0
# Familierelationer og ægteskabslignende forhold              0.0
# Generelle forhold                                           6.0
# Helbredsmæssige forhold                                     0.0
# Kriminelle forhold                                          0.0
# Kønsrelateret forfølgelse                                   0.0
# LGBT                                                        0.0
# Militære forhold                                            3.0
# Modtageforhold                                              0.0
# Nationalitet                                                0.0
# Overgreb                                                    0.0
# Politiske forhold                                           4.0
# Privatretlig forhold                                        0.0
# Privatretlig konflikt                                       0.0
# Religiøse forhold                                           0.0
# Seksuelle forhold                                           0.0
# Tilbageholdelse                                             0.0
# Tilknyt bistand oprørsgruppe                                1.0
# Tortur                                                      2.0
# Udrejseforhold                                              3.0
# Uforholdsmæssig straf                                       0.0
# Ægteskabelige forhold                                       0.0
# Ændrede forhold                                             8.0
# Øvrige modsætningsforhold til myndighederne                 1.0
#
#                                                 Øvrige modsætningsforhold til myndighederne
# Agents of Persecution                                                                  12.0
# Anden kønsrelateret forfølgelse                                                         1.0
# Asylsagsproceduren                                                                      0.0
# Chikane                                                                                 7.0
# Etniske forhold                                                                        14.0
# Familier med børn                                                                       0.0
# Familierelationer og ægteskabslignende forhold                                          1.0
# Generelle forhold                                                                      66.0
# Helbredsmæssige forhold                                                                 7.0
# Kriminelle forhold                                                                      2.0
# Kønsrelateret forfølgelse                                                               0.0
# LGBT                                                                                    1.0
# Militære forhold                                                                       37.0
# Modtageforhold                                                                          0.0
# Nationalitet                                                                            4.0
# Overgreb                                                                                8.0
# Politiske forhold                                                                      37.0
# Privatretlig forhold                                                                   16.0
# Privatretlig konflikt                                                                   1.0
# Religiøse forhold                                                                      14.0
# Seksuelle forhold                                                                       4.0
# Tilbageholdelse                                                                         7.0
# Tilknyt bistand oprørsgruppe                                                            8.0
# Tortur                                                                                  6.0
# Udrejseforhold                                                                          7.0
# Uforholdsmæssig straf                                                                   0.0
# Ægteskabelige forhold                                                                   7.0
# Ændrede forhold                                                                         1.0
# Øvrige modsætningsforhold til myndighederne                                           151.0
#
# [29 rows x 29 columns]

# %%
co_matrix.to_csv('data/co_matrix.csv')
